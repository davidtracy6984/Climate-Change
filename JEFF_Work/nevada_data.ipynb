# %%
#Import the libraries that will be used
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'water_use_NV_converted.csv'
#Making a datframe out of the 
NV_raw = pd.read_csv(path)
NV_raw
# Out:
#       state  county_ID       county_name    year  \
# 0       NaN        NaN               NaN     NaN
# 1    Nevada        1.0  Churchill County  1985.0
# 2    Nevada        1.0  Churchill County  1990.0
# 3    Nevada        1.0  Churchill County  1995.0
# 4    Nevada        1.0  Churchill County  2000.0
# ..      ...        ...               ...     ...
# 115  Nevada      510.0       Carson City  1995.0
# 116  Nevada      510.0       Carson City  2000.0
# 117  Nevada      510.0       Carson City  2005.0
# 118  Nevada      510.0       Carson City  2010.0
# 119  Nevada      510.0       Carson City  2015.0
#
#      Public Supply population served by groundwater, in thousands  \
# 0                                                  NaN
# 1                                                8.150
# 2                                                9.270
# 3                                               12.600
# 4                                               11.310
# ..                                                 ...
# 115                                             27.570
# 116                                             30.350
# 117                                             35.600
# 118                                             35.190
# 119                                             34.388
#
#      Public Supply population served by surface water, in thousands  \
# 0                                                  NaN
# 1                                                 0.05
# 2                                                 0.00
# 3                                                 0.00
# 4                                                 0.00
# ..                                                 ...
# 115                                              14.17
# 116                                              19.65
# 117                                              20.46
# 118                                              20.01
# 119                                              19.93
#
#      Public Supply total population served, in thousands
# 0                                                  NaN
# 1                                                8.200
# 2                                                9.270
# 3                                               12.600
# 4                                               11.310
# ..                                                 ...
# 115                                             41.740
# 116                                             50.000
# 117                                             56.060
# 118                                             55.200
# 119                                             54.318
#
# [120 rows x 7 columns]

# %%
to_numeric = {'year':float,'Public Supply population served by groundwater, in thousands':float,'Public Supply population served by surface water, in thousands':float}
NV_raw2 = NV_raw.astype(to_numeric)
NV_raw2
NV_county_summary = pd.DataFrame(NV_raw2.groupby("county_name").count())

# %%
NV_county_summary["Average Ground Water Used per County"] = pd.DataFrame(NV_raw2.groupby("county_name")["Public Supply population served by groundwater, in thousands"].mean())
NV_county_summary["Average Surface Water Used per County"] = pd.DataFrame(NV_raw2.groupby("county_name")["Public Supply population served by surface water, in thousands"].mean())

NV_county_summary = NV_county_summary[["Average Ground Water Used per County", "Average Surface Water Used per County"]]

NV_county_summary
# Out:
#                    Average Ground Water Used per County  \
# county_name
# Carson City                                   30.374000
# Churchill County                              12.080714
# Clark County                                 121.901429
# Douglas County                                24.478571
# Elko County                                   34.225714
# Esmeralda County                               0.725143
# Eureka County                                  0.981429
# Humboldt County                                9.825429
# Lander County                                  4.205429
# Lincoln County                                 3.699143
# Lyon County                                   28.596714
# Mineral County                                 3.988857
# Nye County                                    16.750571
# Pershing County                                4.309143
# Storey County                                  0.952286
# Washoe County                                 85.280000
# White Pine County                              7.426429
#
#                    Average Surface Water Used per County
# county_name
# Carson City                                    16.408571
# Churchill County                                0.007143
# Clark County                                 1177.752857
# Douglas County                                  8.525571
# Elko County                                     0.687857
# Esmeralda County                                0.000000
# Eureka County                                   0.000000
# Humboldt County                                 0.000000
# Lander County                                   0.022857
# Lincoln County                                  0.000000
# Lyon County                                     0.000000
# Mineral County                                  0.927143
# Nye County                                      0.021429
# Pershing County                                 0.028571
# Storey County                                   1.435714
# Washoe County                                 230.930000
# White Pine County                               0.441429

# %%
datapoints = NV_county_summary[["Average Ground Water Used per County", "Average Surface Water Used per County"]]
datapoints.plot(kind="bar", figsize=(8,6), legend=True)
plt.title("Nevada Water Usage Data")
plt.xlabel('County')
plt.ylabel('Water Use (in thousands)')
plt.legend(["Ground Water", "Surface Water"])
plt.show()

# %%
clark_county = NV_raw.loc[NV_raw["county_name"] == "Clark County",:]

# %%
clark_county_data = clark_county.groupby('year').max()["Public Supply population served by surface water, in thousands"]
clarklastcounty = pd.DataFrame(clark_county_data)
clarklastcounty
# Out:
#         Public Supply population served by surface water, in thousands
# year
# 1985.0                                             402.21
# 1990.0                                             618.00
# 1995.0                                             844.06
# 2000.0                                            1169.60
# 2005.0                                            1522.40
# 2010.0                                            1754.50
# 2015.0                                            1933.50

# %%
clark_county_data.plot(kind='line',x='year',y='Public Supply population served by surface water, in thousands')
plt.title("Clark County Surface Water Usage Data per Year")
plt.xlabel('Year')
plt.ylabel('Surface Water Use (in thousands)')
plt.show()
