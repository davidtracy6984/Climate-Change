# %%
#Import the libraries that will be used
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'water_useAZ_converted.csv'
#Making a datframe out of the 
AZ_raw = pd.read_csv(path)
AZ_raw
# Out:
#        state  county_ID    county_name  year  \
# 0    Arizona          1  Apache County  1985
# 1    Arizona          1  Apache County  1990
# 2    Arizona          1  Apache County  1995
# 3    Arizona          1  Apache County  2000
# 4    Arizona          1  Apache County  2005
# ..       ...        ...            ...   ...
# 100  Arizona         27    Yuma County  1995
# 101  Arizona         27    Yuma County  2000
# 102  Arizona         27    Yuma County  2005
# 103  Arizona         27    Yuma County  2010
# 104  Arizona         27    Yuma County  2015
#
#      Public Supply population served by groundwater, in thousands  \
# 0                                               50.540
# 1                                               34.100
# 2                                               44.330
# 3                                               41.233
# 4                                               46.713
# ..                                                 ...
# 100                                             45.330
# 101                                             43.647
# 102                                             52.887
# 103                                             55.745
# 104                                             58.531
#
#      Public Supply population served by surface water, in thousands  \
# 0                                                0.000
# 1                                                0.150
# 2                                                0.000
# 3                                                0.000
# 4                                                0.000
# ..                                                 ...
# 100                                             68.710
# 101                                            100.699
# 102                                            118.450
# 103                                            130.066
# 104                                            135.804
#
#      Public Supply total population served, in thousands
# 0                                               50.540
# 1                                               34.250
# 2                                               44.330
# 3                                               41.233
# 4                                               46.713
# ..                                                 ...
# 100                                            114.040
# 101                                            144.346
# 102                                            171.337
# 103                                            185.811
# 104                                            194.335
#
# [105 rows x 7 columns]

# %%
to_numeric = {'year':int,'Public Supply population served by groundwater, in thousands':float,'Public Supply population served by surface water, in thousands':float}
AZ_raw2 = AZ_raw.astype(to_numeric)
AZ_raw2
AZ_county_summary = pd.DataFrame(AZ_raw2.groupby("county_name").count())

# %%
AZ_county_summary["Average Ground Water Used per County"] = pd.DataFrame(AZ_raw2.groupby("county_name")["Public Supply population served by groundwater, in thousands"].mean())
AZ_county_summary["Average Surface Water Used per County"] = pd.DataFrame(AZ_raw2.groupby("county_name")["Public Supply population served by surface water, in thousands"].mean())

AZ_county_summary = AZ_county_summary[["Average Ground Water Used per County", "Average Surface Water Used per County"]]
AZ_county_summary
# Out:
#                    Average Ground Water Used per County  \
# county_name
# Apache County                                 44.952571
# Cochise County                                94.437286
# Coconino County                               83.514571
# Gila County                                   40.465286
# Graham County                                 25.542571
# Greenlee County                                5.774857
# La Paz County                                  8.985714
# Maricopa County                              942.711143
# Mohave County                                133.363857
# Navajo County                                 76.494000
# Pima County                                  797.263714
# Pinal County                                 171.902143
# Santa Cruz County                             33.684429
# Yavapai County                               136.888000
# Yuma County                                   42.468571
#
#                    Average Surface Water Used per County
# county_name
# Apache County                                   0.021429
# Cochise County                                  0.024714
# Coconino County                                20.426000
# Gila County                                     0.013857
# Graham County                                   0.000000
# Greenlee County                                 1.051429
# La Paz County                                   2.304857
# Maricopa County                              2023.348571
# Mohave County                                   3.704429
# Navajo County                                   0.000000
# Pima County                                     9.403429
# Pinal County                                   29.035857
# Santa Cruz County                               0.000000
# Yavapai County                                  0.824286
# Yuma County                                    96.171286

# %%
datapoints = AZ_county_summary[["Average Surface Water Used per County"]]
datapoints.plot(kind="bar", figsize=(6,4), color = "b", legend=False)
plt.title("Arizona Surface Water Usage Data")
plt.xlabel('County')
plt.ylabel('Surface Water Use (in thousands)')
plt.show()

# %%
maricopa_county = AZ_raw.loc[AZ_raw["county_name"] == "Maricopa County",:]

# %%
maricopa_county_data = maricopa_county.groupby('year').max()["Public Supply population served by surface water, in thousands"]
maricopalastcounty = pd.DataFrame(maricopa_county_data)
maricopalastcounty
# Out:
#       Public Supply population served by surface water, in thousands
# year
# 1985                                           1043.800
# 1990                                           1114.450
# 1995                                           1582.590
# 2000                                           2395.218
# 2005                                           2533.430
# 2010                                           2374.401
# 2015                                           3119.551

# %%
maricopa_county_data.plot(kind='line',x='year',y='Public Supply population served by surface water, in thousands')
plt.title("Maricopa Surface Water Usage Data per Year")
plt.xlabel('Year')
plt.ylabel('Surface Water Use (in thousands)')
plt.show()
