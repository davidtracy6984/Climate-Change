# %%
#Import the libraries that will be used
import pandas as pd
import glob
import matplotlib.pyplot as plt
import numpy as np

# %%
path = 'JeffProjectPic.csv'
#Making a datframe out of the 
mead_raw = pd.read_csv(path)
mead_raw
# Out:
#     Year  Low Elev  High Elev
# 0   1935    673.50     928.45
# 1   1936    905.20    1025.87
# 2   1937   1021.90    1102.88
# 3   1938   1094.61    1173.56
# 4   1939   1156.10    1183.50
# ..   ...       ...        ...
# 80  2015   1074.71    1089.32
# 81  2016   1071.61    1084.46
# 82  2017   1078.89    1089.80
# 83  2018   1076.38    1088.35
# 84  2019   1081.47    1090.49
#
# [85 rows x 3 columns]

# %%
header_list = ['Year','Low Elevation','High Elevation']
mead_raw.columns = header_list
mead_raw
# Out:
#     Year  Low Elevation  High Elevation
# 0   1935         673.50          928.45
# 1   1936         905.20         1025.87
# 2   1937        1021.90         1102.88
# 3   1938        1094.61         1173.56
# 4   1939        1156.10         1183.50
# ..   ...            ...             ...
# 80  2015        1074.71         1089.32
# 81  2016        1071.61         1084.46
# 82  2017        1078.89         1089.80
# 83  2018        1076.38         1088.35
# 84  2019        1081.47         1090.49
#
# [85 rows x 3 columns]

# %%
#to_numeric = {'Year':int,'Low Elevation':float,'High Elevation':float}
#mead_raw2 = mead_raw.astype(to_numeric)
#mead_raw2

# %%
avg_column = (mead_raw2["Low Elevation"] + mead_raw2["High Elevation"]) / 2
mead_raw2["Average Elevation"] = avg_column
print(mead_raw2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f43260a16be0> in <module>
# ----> 1 avg_column = (mead_raw2["Low Elevation"] + mead_raw2["High Elevation"]) / 2
#       2 mead_raw2["Average Elevation"] = avg_column
#       3 print(mead_raw2)
#
# NameError: name 'mead_raw2' is not defined

# %%
mead_raw2.plot(kind='line',x='Year',y='Low Elevation')
mead_raw2.plot(kind='line',x='Year',y='High Elevation')
mead_raw2.plot(kind='line',x='Year',y='Average Elevation')
